# %%
import pandas as pd
import graphlab as gl

# %%
df = gl.SFrame.read_csv("coupon_list_test.csv")
# Out:
# PROGRESS: Finished parsing file /home/galina/PythonProjects/kaggle_coupon/coupon_list_test.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.067537 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,str,int,int,int,str,str,int,str,str,int,int,int,int,int,int,int,int,int,int,str,str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/galina/PythonProjects/kaggle_coupon/coupon_list_test.csv
# PROGRESS: Parsing completed. Parsed 310 lines in 0.027537 secs.

# %%
df
# Out:
# Columns:
# 	CAPSULE_TEXT	str
# 	GENRE_NAME	str
# 	PRICE_RATE	int
# 	CATALOG_PRICE	int
# 	DISCOUNT_PRICE	int
# 	DISPFROM	str
# 	DISPEND	str
# 	DISPPERIOD	int
# 	VALIDFROM	str
# 	VALIDEND	str
# 	VALIDPERIOD	int
# 	USABLE_DATE_MON	int
# 	USABLE_DATE_TUE	int
# 	USABLE_DATE_WED	int
# 	USABLE_DATE_THU	int
# 	USABLE_DATE_FRI	int
# 	USABLE_DATE_SAT	int
# 	USABLE_DATE_SUN	int
# 	USABLE_DATE_HOLIDAY	int
# 	USABLE_DATE_BEFORE_HOLIDAY	int
# 	large_area_name	str
# 	ken_name	str
# 	small_area_name	str
# 	COUPON_ID_hash	str
#
# Rows: 310
#
# Data:
# +--------------+------------+------------+---------------+----------------+
# | CAPSULE_TEXT | GENRE_NAME | PRICE_RATE | CATALOG_PRICE | DISCOUNT_PRICE |
# +--------------+------------+------------+---------------+----------------+
# |    グルメ    |   グルメ   |     52     |      5659     |      2690      |
# |    グルメ    |   グルメ   |     52     |     18000     |      8500      |
# |    グルメ    |   グルメ   |     51     |      7200     |      3480      |
# ...
